# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("MySparkApp") \
    .master("local[*]") \
    .getOrCreate()

# Access SparkContext from SparkSession
sc = spark.sparkContext

# %%
df= spark.read.format('csv').option('inferSchema',True).option('header',True).load('/users/shubh/Data Engineering/BigMart Sales.csv')

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
df_json = spark.read.format('json').option('inferedSchema', True)\
    .option('header', True)\
        .option('multiLine',False).load('/users/shubh/Data Engineering/drivers.json')

# %%
df.filter(col('Outlet_Location_Type').isin('Tier 1','Tier 2') & col('Outlet_Size').isNull()).limit(20).toPandas()

# %%
df.limit(20).toPandas()

# %%
df.show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# |          FDA15|        9.3|         Low Fat|    0.016047301|               Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         3735.138|
# |          DRC01|       5.92|         Regular|    0.019278216|         Soft Drinks| 48.2692|           OUT018|                     2009|     Medium|              Tier 3|Supermarket Type2|         443.4228|
# |          FDN15|       17.5|         Low Fat|    0.016760075|                Meat| 141.618|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|          2097.27|
# |          FDX07|       19.2|         Regular|            0.0|Fruits and Vegeta...| 182.095|           OUT010|                     1998|       NULL|              Tier 3|    Grocery Store|           732.38|
# |          NCD19|       8.93|         Low Fat|            0.0|           Household| 53.8614|           OUT013|                     1987|       High|              Tier 3|Supermarket Type1|         994.7052|
# |          FDP36|     10.395|         Regular|            0.0|        Baking Goods| 51.4008|           OUT018|                     2009|     Medium|              Tier 3|Supermarket Type2|         556.6088|
# |          FDO10|      13.65|         Regular|    0.012741089|         Snack Foods| 57.6588|           OUT013|                     1987|       High|              Tier 3|Supermarket Type1|         343.5528|
# |          FDP10|       NULL|         Low Fat|    0.127469857|         Snack Foods|107.7622|           OUT027|                     1985|     Medium|              Tier 3|Supermarket Type3|        4022.7636|
# |          FDH17|       16.2|         Regular|    0.016687114|        Frozen Foods| 96.9726|           OUT045|                     2002|       NULL|              Tier 2|Supermarket Type1|        1076.5986|
# |          FDU28|       19.2|         Regular|     0.09444959|        Frozen Foods|187.8214|           OUT017|                     2007|       NULL|              Tier 2|Supermarket Type1|         4710.535|
# |          FDY07|       11.8|         Low Fat|            0.0|Fruits and Vegeta...| 45.5402|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|        1516.0266|
# |          FDA03|       18.5|         Regular|    0.045463773|               Dairy|144.1102|           OUT046|                     1997|      Small|              Tier 1|Supermarket Type1|         2187.153|
# |          FDX32|       15.1|         Regular|      0.1000135|Fruits and Vegeta...|145.4786|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|        1589.2646|
# |          FDS46|       17.6|         Regular|    0.047257328|         Snack Foods|119.6782|           OUT046|                     1997|      Small|              Tier 1|Supermarket Type1|        2145.2076|
# |          FDF32|      16.35|         Low Fat|      0.0680243|Fruits and Vegeta...|196.4426|           OUT013|                     1987|       High|              Tier 3|Supermarket Type1|         1977.426|
# |          FDP49|        9.0|         Regular|    0.069088961|           Breakfast| 56.3614|           OUT046|                     1997|      Small|              Tier 1|Supermarket Type1|        1547.3192|
# |          NCB42|       11.8|         Low Fat|    0.008596051|  Health and Hygiene|115.3492|           OUT018|                     2009|     Medium|              Tier 3|Supermarket Type2|        1621.8888|
# |          FDP49|        9.0|         Regular|    0.069196376|           Breakfast| 54.3614|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         718.3982|
# |          DRI11|       NULL|         Low Fat|    0.034237682|         Hard Drinks|113.2834|           OUT027|                     1985|     Medium|              Tier 3|Supermarket Type3|         2303.668|
# |          FDU02|      13.35|         Low Fat|     0.10249212|               Dairy|230.5352|           OUT035|                     2004|      Small|              Tier 2|Supermarket Type1|        2748.4224|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### Column Rename: withColumnRenamed

# %%
df.withColumnRenamed('Item_Weight','Item_Wt').limit(10).toPandas()

# %% [markdown]
# ### withColumn

# %% [markdown]
# ## Scenario 1

# %%
df_new = df.withColumn('Flag',lit('New'))

# %%
df_new.limit(10).toPandas()

# %%
df_new.withColumn('Multiple', col('Item_Weight')*col('Item_MRP')).toPandas()

# %% [markdown]
# ### Scenario 2

# %%
df_new.withColumn('Item_Fat_Content', regexp_replace('Item_Fat_Content','Regular','Reg'))\
        .withColumn('Item_Fat_Content', regexp_replace('Item_Fat_Content','Low Fat','LF')).toPandas()

# %% [markdown]
# ### Type Casting

# %%
df_new1= df.withColumn('Item_Weight', col('Item_Weight').cast(StringType()))

# %%
df_new1.printSchema()

# %% [markdown]
# # Sort

# %% [markdown]
# ## Scenario 1

# %%
df.sort(col('Item_Weight').desc()).limit(50).toPandas()

# %%
df.sort(col('Item_Visibility').asc()).limit(10).toPandas()

# %% [markdown]
# ## Scenario 2

# %%
df.sort(['Item_Weight','Item_MRP'], ascending= [0,1]).limit(100).toPandas()

# %% [markdown]
# # limit

# %%
df.limit(10).show()

# %% [markdown]
# # DROP

# %%
df.drop('Item_Visibility').limit(10).show()

# %%
df.limit(10).toPandas()

# %%
df.drop('Item_Visibility','Outlet_Type').limit(10).toPandas()

# %% [markdown]
# # Drop Duplicates

# %% [markdown]
# ### Scenario 1 (table level)

# %%
df.toPandas()

# %%
df.dropDuplicates().toPandas()

# %%
df.distinct().toPandas()

# %% [markdown]
# ### Scenario 2 (column level)

# %%
df.drop_duplicates(subset=['Item_Type']).toPandas()

# %% [markdown]
# # Union

# %% [markdown]
# ### creating Dataframes

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Data and schema for df1
data1 = [('1', 'kad'), ('2', 'sid')]
schema1 = 'id STRING, name STRING'
df1 = spark.createDataFrame(data1, schema1)

# Data and schema for df2
data2 = [('3', 'rahul'), ('4', 'jas')]
schema2 = 'id STRING, name STRING'
df2 = spark.createDataFrame(data2, schema2)

# Show the dataframes
df1.show()
df2.show()
# Out:
# +---+----+
# | id|name|
# +---+----+
# |  1| kad|
# |  2| sid|
# +---+----+
#
# +---+-----+
# | id| name|
# +---+-----+
# |  3|rahul|
# |  4|  jas|
# +---+-----+

# %%
df1.union(df2).show()
# Out:
# +---+-----+
# | id| name|
# +---+-----+
# |  1|  kad|
# |  2|  sid|
# |  3|rahul|
# |  4|  jas|
# +---+-----+

# %%
data1 = [('kad','1'), ('sid','2')]
schema1 = 'name STRING,id STRING'
df1 = spark.createDataFrame(data1, schema1)

# Data and schema for df2
data2 = [('3', 'rahul'), ('4', 'jas')]
schema2 = 'id STRING, name STRING'
df2 = spark.createDataFrame(data2, schema2)

# Show the dataframes
df1.show()
df2.show()
df1.union(df2).show()
# Out:
# +----+---+
# |name| id|
# +----+---+
# | kad|  1|
# | sid|  2|
# +----+---+
#
# +---+-----+
# | id| name|
# +---+-----+
# |  3|rahul|
# |  4|  jas|
# +---+-----+
#
# +----+-----+
# |name|   id|
# +----+-----+
# | kad|    1|
# | sid|    2|
# |   3|rahul|
# |   4|  jas|
# +----+-----+

# %% [markdown]
# ### unionByName

# %%
df1.unionByName(df2).show()
# Out:
# +-----+---+
# | name| id|
# +-----+---+
# |  kad|  1|
# |  sid|  2|
# |rahul|  3|
# |  jas|  4|
# +-----+---+

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark.range(5).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %% [markdown]
# # String Functions

# %%
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.select(initcap('Item_Type').alias('Item_Type')).toPandas()
# Out:
#                   Item_Type
# 0                     Dairy
# 1               Soft Drinks
# 2                      Meat
# 3     Fruits And Vegetables
# 4                 Household
# ...                     ...
# 8518            Snack Foods
# 8519           Baking Goods
# 8520     Health And Hygiene
# 8521            Snack Foods
# 8522            Soft Drinks
#
# [8523 rows x 1 columns]

# %%
df.select(upper('Item_Type').alias('Item_Type')).toPandas()
# Out:
#                   Item_Type
# 0                     DAIRY
# 1               SOFT DRINKS
# 2                      MEAT
# 3     FRUITS AND VEGETABLES
# 4                 HOUSEHOLD
# ...                     ...
# 8518            SNACK FOODS
# 8519           BAKING GOODS
# 8520     HEALTH AND HYGIENE
# 8521            SNACK FOODS
# 8522            SOFT DRINKS
#
# [8523 rows x 1 columns]

# %%
df.select(lower('Item_Type').alias('Item_Type')).toPandas()
# Out:
#                   Item_Type
# 0                     dairy
# 1               soft drinks
# 2                      meat
# 3     fruits and vegetables
# 4                 household
# ...                     ...
# 8518            snack foods
# 8519           baking goods
# 8520     health and hygiene
# 8521            snack foods
# 8522            soft drinks
#
# [8523 rows x 1 columns]

# %% [markdown]
# # Data functions

# %%
df= df.withColumn('curr_date',current_date())
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales   curr_date
# 0     Supermarket Type1          3735.1380  2025-06-08
# 1     Supermarket Type2           443.4228  2025-06-08
# 2     Supermarket Type1          2097.2700  2025-06-08
# 3         Grocery Store           732.3800  2025-06-08
# 4     Supermarket Type1           994.7052  2025-06-08
# ...                 ...                ...         ...
# 8518  Supermarket Type1          2778.3834  2025-06-08
# 8519  Supermarket Type1           549.2850  2025-06-08
# 8520  Supermarket Type1          1193.1136  2025-06-08
# 8521  Supermarket Type2          1845.5976  2025-06-08
# 8522  Supermarket Type1           765.6700  2025-06-08
#
# [8523 rows x 13 columns]

# %%
df= df.withColumn('week_after',date_add('curr_date',7))
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales   curr_date  week_after week_before
# 0     Supermarket Type1          3735.1380  2025-06-15  2025-06-22  2025-06-08
# 1     Supermarket Type2           443.4228  2025-06-15  2025-06-22  2025-06-08
# 2     Supermarket Type1          2097.2700  2025-06-15  2025-06-22  2025-06-08
# 3         Grocery Store           732.3800  2025-06-15  2025-06-22  2025-06-08
# 4     Supermarket Type1           994.7052  2025-06-15  2025-06-22  2025-06-08
# ...                 ...                ...         ...         ...         ...
# 8518  Supermarket Type1          2778.3834  2025-06-15  2025-06-22  2025-06-08
# 8519  Supermarket Type1           549.2850  2025-06-15  2025-06-22  2025-06-08
# 8520  Supermarket Type1          1193.1136  2025-06-15  2025-06-22  2025-06-08
# 8521  Supermarket Type2          1845.5976  2025-06-15  2025-06-22  2025-06-08
# 8522  Supermarket Type1           765.6700  2025-06-15  2025-06-22  2025-06-08
#
# [8523 rows x 15 columns]

# %% [markdown]
# ### date substract

# %%
df= df.withColumn('week_before',date_sub('curr_date',7))
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales   curr_date  week_after week_before
# 0     Supermarket Type1          3735.1380  2025-06-15  2025-06-22  2025-06-08
# 1     Supermarket Type2           443.4228  2025-06-15  2025-06-22  2025-06-08
# 2     Supermarket Type1          2097.2700  2025-06-15  2025-06-22  2025-06-08
# 3         Grocery Store           732.3800  2025-06-15  2025-06-22  2025-06-08
# 4     Supermarket Type1           994.7052  2025-06-15  2025-06-22  2025-06-08
# ...                 ...                ...         ...         ...         ...
# 8518  Supermarket Type1          2778.3834  2025-06-15  2025-06-22  2025-06-08
# 8519  Supermarket Type1           549.2850  2025-06-15  2025-06-22  2025-06-08
# 8520  Supermarket Type1          1193.1136  2025-06-15  2025-06-22  2025-06-08
# 8521  Supermarket Type2          1845.5976  2025-06-15  2025-06-22  2025-06-08
# 8522  Supermarket Type1           765.6700  2025-06-15  2025-06-22  2025-06-08
#
# [8523 rows x 15 columns]

# %%
df= df.withColumn('week_before',date_add('curr_date',-7))
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales   curr_date  week_after  \
# 0     Supermarket Type1          3735.1380  2025-06-15  2025-06-22
# 1     Supermarket Type2           443.4228  2025-06-15  2025-06-22
# 2     Supermarket Type1          2097.2700  2025-06-15  2025-06-22
# 3         Grocery Store           732.3800  2025-06-15  2025-06-22
# 4     Supermarket Type1           994.7052  2025-06-15  2025-06-22
# ...                 ...                ...         ...         ...
# 8518  Supermarket Type1          2778.3834  2025-06-15  2025-06-22
# 8519  Supermarket Type1           549.2850  2025-06-15  2025-06-22
# 8520  Supermarket Type1          1193.1136  2025-06-15  2025-06-22
# 8521  Supermarket Type2          1845.5976  2025-06-15  2025-06-22
# 8522  Supermarket Type1           765.6700  2025-06-15  2025-06-22
#
#      week_before  date_diff
# 0     2025-06-08         14
# 1     2025-06-08         14
# 2     2025-06-08         14
# 3     2025-06-08         14
# 4     2025-06-08         14
# ...          ...        ...
# 8518  2025-06-08         14
# 8519  2025-06-08         14
# 8520  2025-06-08         14
# 8521  2025-06-08         14
# 8522  2025-06-08         14
#
# [8523 rows x 16 columns]

# %%
df=df.withColumn('date_diff',date_diff('week_after','week_before'))
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales   curr_date  week_after  \
# 0     Supermarket Type1          3735.1380  2025-06-15  2025-06-22
# 1     Supermarket Type2           443.4228  2025-06-15  2025-06-22
# 2     Supermarket Type1          2097.2700  2025-06-15  2025-06-22
# 3         Grocery Store           732.3800  2025-06-15  2025-06-22
# 4     Supermarket Type1           994.7052  2025-06-15  2025-06-22
# ...                 ...                ...         ...         ...
# 8518  Supermarket Type1          2778.3834  2025-06-15  2025-06-22
# 8519  Supermarket Type1           549.2850  2025-06-15  2025-06-22
# 8520  Supermarket Type1          1193.1136  2025-06-15  2025-06-22
# 8521  Supermarket Type2          1845.5976  2025-06-15  2025-06-22
# 8522  Supermarket Type1           765.6700  2025-06-15  2025-06-22
#
#      week_before  date_diff
# 0     2025-06-08         14
# 1     2025-06-08         14
# 2     2025-06-08         14
# 3     2025-06-08         14
# 4     2025-06-08         14
# ...          ...        ...
# 8518  2025-06-08         14
# 8519  2025-06-08         14
# 8520  2025-06-08         14
# 8521  2025-06-08         14
# 8522  2025-06-08         14
#
# [8523 rows x 16 columns]

# %% [markdown]
# ## Date format

# %%
df = df.withColumn('week_before', date_format('week_before', 'dd-MM-yyyy'))
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales   curr_date  week_after  \
# 0     Supermarket Type1          3735.1380  2025-06-15  2025-06-22
# 1     Supermarket Type2           443.4228  2025-06-15  2025-06-22
# 2     Supermarket Type1          2097.2700  2025-06-15  2025-06-22
# 3         Grocery Store           732.3800  2025-06-15  2025-06-22
# 4     Supermarket Type1           994.7052  2025-06-15  2025-06-22
# ...                 ...                ...         ...         ...
# 8518  Supermarket Type1          2778.3834  2025-06-15  2025-06-22
# 8519  Supermarket Type1           549.2850  2025-06-15  2025-06-22
# 8520  Supermarket Type1          1193.1136  2025-06-15  2025-06-22
# 8521  Supermarket Type2          1845.5976  2025-06-15  2025-06-22
# 8522  Supermarket Type1           765.6700  2025-06-15  2025-06-22
#
#      week_before  date_diff
# 0     08-06-2025         14
# 1     08-06-2025         14
# 2     08-06-2025         14
# 3     08-06-2025         14
# 4     08-06-2025         14
# ...          ...        ...
# 8518  08-06-2025         14
# 8519  08-06-2025         14
# 8520  08-06-2025         14
# 8521  08-06-2025         14
# 8522  08-06-2025         14
#
# [8523 rows x 16 columns]

# %%
df.printSchema()
# Out:
# root
#  |-- Item_Identifier: string (nullable = true)
#  |-- Item_Weight: double (nullable = true)
#  |-- Item_Fat_Content: string (nullable = true)
#  |-- Item_Visibility: double (nullable = true)
#  |-- Item_Type: string (nullable = true)
#  |-- Item_MRP: double (nullable = true)
#  |-- Outlet_Identifier: string (nullable = true)
#  |-- Outlet_Establishment_Year: integer (nullable = true)
#  |-- Outlet_Size: string (nullable = true)
#  |-- Outlet_Location_Type: string (nullable = true)
#  |-- Outlet_Type: string (nullable = true)
#  |-- Item_Outlet_Sales: double (nullable = true)
#  |-- curr_date: date (nullable = false)
#  |-- week_after: date (nullable = false)
#  |-- week_before: date (nullable = false)
#  |-- date_diff: integer (nullable = false)

# %%
df.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %% [markdown]
# # Handling nulls
# ### Droping nulls

# %%
df.dropna('all').toPandas() # all colums null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.dropna('any').toPandas()  #any column is null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              NCD19        8.930          Low Fat         0.000000
# 4              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 4645           FDF53       20.750              reg         0.083607
# 4646           FDF22        6.865          Low Fat         0.056783
# 4647           NCJ29       10.600          Low Fat         0.035186
# 4648           FDN46        7.210          Regular         0.145221
# 4649           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3              Household   53.8614            OUT013
# 4           Baking Goods   51.4008            OUT018
# ...                  ...       ...               ...
# 4645        Frozen Foods  178.8318            OUT046
# 4646         Snack Foods  214.5218            OUT013
# 4647  Health and Hygiene   85.1224            OUT035
# 4648         Snack Foods  103.1332            OUT018
# 4649         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1987        High               Tier 3
# 4                          2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 4645                       1997       Small               Tier 1
# 4646                       1987        High               Tier 3
# 4647                       2004       Small               Tier 2
# 4648                       2009      Medium               Tier 3
# 4649                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3     Supermarket Type1           994.7052
# 4     Supermarket Type2           556.6088
# ...                 ...                ...
# 4645  Supermarket Type1          3608.6360
# 4646  Supermarket Type1          2778.3834
# 4647  Supermarket Type1          1193.1136
# 4648  Supermarket Type2          1845.5976
# 4649  Supermarket Type1           765.6700
#
# [4650 rows x 12 columns]

# %%
df.dropna(subset=['Outlet_Size']).toPandas() #specific column
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              NCD19        8.930          Low Fat         0.000000
# 4              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 6108           FDF53       20.750              reg         0.083607
# 6109           FDF22        6.865          Low Fat         0.056783
# 6110           NCJ29       10.600          Low Fat         0.035186
# 6111           FDN46        7.210          Regular         0.145221
# 6112           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3              Household   53.8614            OUT013
# 4           Baking Goods   51.4008            OUT018
# ...                  ...       ...               ...
# 6108        Frozen Foods  178.8318            OUT046
# 6109         Snack Foods  214.5218            OUT013
# 6110  Health and Hygiene   85.1224            OUT035
# 6111         Snack Foods  103.1332            OUT018
# 6112         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1987        High               Tier 3
# 4                          2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 6108                       1997       Small               Tier 1
# 6109                       1987        High               Tier 3
# 6110                       2004       Small               Tier 2
# 6111                       2009      Medium               Tier 3
# 6112                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3     Supermarket Type1           994.7052
# 4     Supermarket Type2           556.6088
# ...                 ...                ...
# 6108  Supermarket Type1          3608.6360
# 6109  Supermarket Type1          2778.3834
# 6110  Supermarket Type1          1193.1136
# 6111  Supermarket Type2          1845.5976
# 6112  Supermarket Type1           765.6700
#
# [6113 rows x 12 columns]

# %% [markdown]
# ### Filling Nulls

# %%
df.fillna('Not available').toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year    Outlet_Size Outlet_Location_Type  \
# 0                          1999         Medium               Tier 1
# 1                          2009         Medium               Tier 3
# 2                          1999         Medium               Tier 1
# 3                          1998  Not available               Tier 3
# 4                          1987           High               Tier 3
# ...                         ...            ...                  ...
# 8518                       1987           High               Tier 3
# 8519                       2002  Not available               Tier 2
# 8520                       2004          Small               Tier 2
# 8521                       2009         Medium               Tier 3
# 8522                       1997          Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.fillna('Not Available',subset=['Outlet_Size']).show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-------------+--------------------+-----------------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|  Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-------------+--------------------+-----------------+-----------------+
# |          FDA15|        9.3|         Low Fat|    0.016047301|               Dairy|249.8092|           OUT049|                     1999|       Medium|              Tier 1|Supermarket Type1|         3735.138|
# |          DRC01|       5.92|         Regular|    0.019278216|         Soft Drinks| 48.2692|           OUT018|                     2009|       Medium|              Tier 3|Supermarket Type2|         443.4228|
# |          FDN15|       17.5|         Low Fat|    0.016760075|                Meat| 141.618|           OUT049|                     1999|       Medium|              Tier 1|Supermarket Type1|          2097.27|
# |          FDX07|       19.2|         Regular|            0.0|Fruits and Vegeta...| 182.095|           OUT010|                     1998|Not Available|              Tier 3|    Grocery Store|           732.38|
# |          NCD19|       8.93|         Low Fat|            0.0|           Household| 53.8614|           OUT013|                     1987|         High|              Tier 3|Supermarket Type1|         994.7052|
# |          FDP36|     10.395|         Regular|            0.0|        Baking Goods| 51.4008|           OUT018|                     2009|       Medium|              Tier 3|Supermarket Type2|         556.6088|
# |          FDO10|      13.65|         Regular|    0.012741089|         Snack Foods| 57.6588|           OUT013|                     1987|         High|              Tier 3|Supermarket Type1|         343.5528|
# |          FDP10|       NULL|         Low Fat|    0.127469857|         Snack Foods|107.7622|           OUT027|                     1985|       Medium|              Tier 3|Supermarket Type3|        4022.7636|
# |          FDH17|       16.2|         Regular|    0.016687114|        Frozen Foods| 96.9726|           OUT045|                     2002|Not Available|              Tier 2|Supermarket Type1|        1076.5986|
# |          FDU28|       19.2|         Regular|     0.09444959|        Frozen Foods|187.8214|           OUT017|                     2007|Not Available|              Tier 2|Supermarket Type1|         4710.535|
# |          FDY07|       11.8|         Low Fat|            0.0|Fruits and Vegeta...| 45.5402|           OUT049|                     1999|       Medium|              Tier 1|Supermarket Type1|        1516.0266|
# |          FDA03|       18.5|         Regular|    0.045463773|               Dairy|144.1102|           OUT046|                     1997|        Small|              Tier 1|Supermarket Type1|         2187.153|
# |          FDX32|       15.1|         Regular|      0.1000135|Fruits and Vegeta...|145.4786|           OUT049|                     1999|       Medium|              Tier 1|Supermarket Type1|        1589.2646|
# |          FDS46|       17.6|         Regular|    0.047257328|         Snack Foods|119.6782|           OUT046|                     1997|        Small|              Tier 1|Supermarket Type1|        2145.2076|
# |          FDF32|      16.35|         Low Fat|      0.0680243|Fruits and Vegeta...|196.4426|           OUT013|                     1987|         High|              Tier 3|Supermarket Type1|         1977.426|
# |          FDP49|        9.0|         Regular|    0.069088961|           Breakfast| 56.3614|           OUT046|                     1997|        Small|              Tier 1|Supermarket Type1|        1547.3192|
# |          NCB42|       11.8|         Low Fat|    0.008596051|  Health and Hygiene|115.3492|           OUT018|                     2009|       Medium|              Tier 3|Supermarket Type2|        1621.8888|
# |          FDP49|        9.0|         Regular|    0.069196376|           Breakfast| 54.3614|           OUT049|                     1999|       Medium|              Tier 1|Supermarket Type1|         718.3982|
# |          DRI11|       NULL|         Low Fat|    0.034237682|         Hard Drinks|113.2834|           OUT027|                     1985|       Medium|              Tier 3|Supermarket Type3|         2303.668|
# |          FDU02|      13.35|         Low Fat|     0.10249212|               Dairy|230.5352|           OUT035|                     2004|        Small|              Tier 2|Supermarket Type1|        2748.4224|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-------------+--------------------+-----------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# # Split and indexing
# ### Split

# %%
df.withColumn('Outlet_Type',split('Outlet_Type', ' ')).show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+--------------------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|         Outlet_Type|Item_Outlet_Sales|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+--------------------+-----------------+
# |          FDA15|        9.3|         Low Fat|    0.016047301|               Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|[Supermarket, Type1]|         3735.138|
# |          DRC01|       5.92|         Regular|    0.019278216|         Soft Drinks| 48.2692|           OUT018|                     2009|     Medium|              Tier 3|[Supermarket, Type2]|         443.4228|
# |          FDN15|       17.5|         Low Fat|    0.016760075|                Meat| 141.618|           OUT049|                     1999|     Medium|              Tier 1|[Supermarket, Type1]|          2097.27|
# |          FDX07|       19.2|         Regular|            0.0|Fruits and Vegeta...| 182.095|           OUT010|                     1998|       NULL|              Tier 3|    [Grocery, Store]|           732.38|
# |          NCD19|       8.93|         Low Fat|            0.0|           Household| 53.8614|           OUT013|                     1987|       High|              Tier 3|[Supermarket, Type1]|         994.7052|
# |          FDP36|     10.395|         Regular|            0.0|        Baking Goods| 51.4008|           OUT018|                     2009|     Medium|              Tier 3|[Supermarket, Type2]|         556.6088|
# |          FDO10|      13.65|         Regular|    0.012741089|         Snack Foods| 57.6588|           OUT013|                     1987|       High|              Tier 3|[Supermarket, Type1]|         343.5528|
# |          FDP10|       NULL|         Low Fat|    0.127469857|         Snack Foods|107.7622|           OUT027|                     1985|     Medium|              Tier 3|[Supermarket, Type3]|        4022.7636|
# |          FDH17|       16.2|         Regular|    0.016687114|        Frozen Foods| 96.9726|           OUT045|                     2002|       NULL|              Tier 2|[Supermarket, Type1]|        1076.5986|
# |          FDU28|       19.2|         Regular|     0.09444959|        Frozen Foods|187.8214|           OUT017|                     2007|       NULL|              Tier 2|[Supermarket, Type1]|         4710.535|
# |          FDY07|       11.8|         Low Fat|            0.0|Fruits and Vegeta...| 45.5402|           OUT049|                     1999|     Medium|              Tier 1|[Supermarket, Type1]|        1516.0266|
# |          FDA03|       18.5|         Regular|    0.045463773|               Dairy|144.1102|           OUT046|                     1997|      Small|              Tier 1|[Supermarket, Type1]|         2187.153|
# |          FDX32|       15.1|         Regular|      0.1000135|Fruits and Vegeta...|145.4786|           OUT049|                     1999|     Medium|              Tier 1|[Supermarket, Type1]|        1589.2646|
# |          FDS46|       17.6|         Regular|    0.047257328|         Snack Foods|119.6782|           OUT046|                     1997|      Small|              Tier 1|[Supermarket, Type1]|        2145.2076|
# |          FDF32|      16.35|         Low Fat|      0.0680243|Fruits and Vegeta...|196.4426|           OUT013|                     1987|       High|              Tier 3|[Supermarket, Type1]|         1977.426|
# |          FDP49|        9.0|         Regular|    0.069088961|           Breakfast| 56.3614|           OUT046|                     1997|      Small|              Tier 1|[Supermarket, Type1]|        1547.3192|
# |          NCB42|       11.8|         Low Fat|    0.008596051|  Health and Hygiene|115.3492|           OUT018|                     2009|     Medium|              Tier 3|[Supermarket, Type2]|        1621.8888|
# |          FDP49|        9.0|         Regular|    0.069196376|           Breakfast| 54.3614|           OUT049|                     1999|     Medium|              Tier 1|[Supermarket, Type1]|         718.3982|
# |          DRI11|       NULL|         Low Fat|    0.034237682|         Hard Drinks|113.2834|           OUT027|                     1985|     Medium|              Tier 3|[Supermarket, Type3]|         2303.668|
# |          FDU02|      13.35|         Low Fat|     0.10249212|               Dairy|230.5352|           OUT035|                     2004|      Small|              Tier 2|[Supermarket, Type1]|        2748.4224|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+--------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### indexing

# %%
df.withColumn('Outlet_Type',split('Outlet_Type', ' ')[1]).show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|Outlet_Type|Item_Outlet_Sales|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------+-----------------+
# |          FDA15|        9.3|         Low Fat|    0.016047301|               Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|      Type1|         3735.138|
# |          DRC01|       5.92|         Regular|    0.019278216|         Soft Drinks| 48.2692|           OUT018|                     2009|     Medium|              Tier 3|      Type2|         443.4228|
# |          FDN15|       17.5|         Low Fat|    0.016760075|                Meat| 141.618|           OUT049|                     1999|     Medium|              Tier 1|      Type1|          2097.27|
# |          FDX07|       19.2|         Regular|            0.0|Fruits and Vegeta...| 182.095|           OUT010|                     1998|       NULL|              Tier 3|      Store|           732.38|
# |          NCD19|       8.93|         Low Fat|            0.0|           Household| 53.8614|           OUT013|                     1987|       High|              Tier 3|      Type1|         994.7052|
# |          FDP36|     10.395|         Regular|            0.0|        Baking Goods| 51.4008|           OUT018|                     2009|     Medium|              Tier 3|      Type2|         556.6088|
# |          FDO10|      13.65|         Regular|    0.012741089|         Snack Foods| 57.6588|           OUT013|                     1987|       High|              Tier 3|      Type1|         343.5528|
# |          FDP10|       NULL|         Low Fat|    0.127469857|         Snack Foods|107.7622|           OUT027|                     1985|     Medium|              Tier 3|      Type3|        4022.7636|
# |          FDH17|       16.2|         Regular|    0.016687114|        Frozen Foods| 96.9726|           OUT045|                     2002|       NULL|              Tier 2|      Type1|        1076.5986|
# |          FDU28|       19.2|         Regular|     0.09444959|        Frozen Foods|187.8214|           OUT017|                     2007|       NULL|              Tier 2|      Type1|         4710.535|
# |          FDY07|       11.8|         Low Fat|            0.0|Fruits and Vegeta...| 45.5402|           OUT049|                     1999|     Medium|              Tier 1|      Type1|        1516.0266|
# |          FDA03|       18.5|         Regular|    0.045463773|               Dairy|144.1102|           OUT046|                     1997|      Small|              Tier 1|      Type1|         2187.153|
# |          FDX32|       15.1|         Regular|      0.1000135|Fruits and Vegeta...|145.4786|           OUT049|                     1999|     Medium|              Tier 1|      Type1|        1589.2646|
# |          FDS46|       17.6|         Regular|    0.047257328|         Snack Foods|119.6782|           OUT046|                     1997|      Small|              Tier 1|      Type1|        2145.2076|
# |          FDF32|      16.35|         Low Fat|      0.0680243|Fruits and Vegeta...|196.4426|           OUT013|                     1987|       High|              Tier 3|      Type1|         1977.426|
# |          FDP49|        9.0|         Regular|    0.069088961|           Breakfast| 56.3614|           OUT046|                     1997|      Small|              Tier 1|      Type1|        1547.3192|
# |          NCB42|       11.8|         Low Fat|    0.008596051|  Health and Hygiene|115.3492|           OUT018|                     2009|     Medium|              Tier 3|      Type2|        1621.8888|
# |          FDP49|        9.0|         Regular|    0.069196376|           Breakfast| 54.3614|           OUT049|                     1999|     Medium|              Tier 1|      Type1|         718.3982|
# |          DRI11|       NULL|         Low Fat|    0.034237682|         Hard Drinks|113.2834|           OUT027|                     1985|     Medium|              Tier 3|      Type3|         2303.668|
# |          FDU02|      13.35|         Low Fat|     0.10249212|               Dairy|230.5352|           OUT035|                     2004|      Small|              Tier 2|      Type1|        2748.4224|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------+-----------------+
# only showing top 20 rows

# %% [markdown]
# # Explode

# %%
df_exp =df.withColumn('Outlet_Type',split('Outlet_Type', ' '))

df_exp.toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#                Outlet_Type  Item_Outlet_Sales
# 0     [Supermarket, Type1]          3735.1380
# 1     [Supermarket, Type2]           443.4228
# 2     [Supermarket, Type1]          2097.2700
# 3         [Grocery, Store]           732.3800
# 4     [Supermarket, Type1]           994.7052
# ...                    ...                ...
# 8518  [Supermarket, Type1]          2778.3834
# 8519  [Supermarket, Type1]           549.2850
# 8520  [Supermarket, Type1]          1193.1136
# 8521  [Supermarket, Type2]          1845.5976
# 8522  [Supermarket, Type1]           765.6700
#
# [8523 rows x 12 columns]

# %%
df_exp.withColumn('Outlet_Type',explode('Outlet_Type')).toPandas()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               FDA15         9.30          Low Fat         0.016047
# 2               DRC01         5.92          Regular         0.019278
# 3               DRC01         5.92          Regular         0.019278
# 4               FDN15        17.50          Low Fat         0.016760
# ...               ...          ...              ...              ...
# 17041           NCJ29        10.60          Low Fat         0.035186
# 17042           FDN46         7.21          Regular         0.145221
# 17043           FDN46         7.21          Regular         0.145221
# 17044           DRG01        14.80          Low Fat         0.044878
# 17045           DRG01        14.80          Low Fat         0.044878
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 1                   Dairy  249.8092            OUT049
# 2             Soft Drinks   48.2692            OUT018
# 3             Soft Drinks   48.2692            OUT018
# 4                    Meat  141.6180            OUT049
# ...                   ...       ...               ...
# 17041  Health and Hygiene   85.1224            OUT035
# 17042         Snack Foods  103.1332            OUT018
# 17043         Snack Foods  103.1332            OUT018
# 17044         Soft Drinks   75.4670            OUT046
# 17045         Soft Drinks   75.4670            OUT046
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           1999      Medium               Tier 1
# 2                           2009      Medium               Tier 3
# 3                           2009      Medium               Tier 3
# 4                           1999      Medium               Tier 1
# ...                          ...         ...                  ...
# 17041                       2004       Small               Tier 2
# 17042                       2009      Medium               Tier 3
# 17043                       2009      Medium               Tier 3
# 17044                       1997       Small               Tier 1
# 17045                       1997       Small               Tier 1
#
#        Outlet_Type  Item_Outlet_Sales
# 0      Supermarket          3735.1380
# 1            Type1          3735.1380
# 2      Supermarket           443.4228
# 3            Type2           443.4228
# 4      Supermarket          2097.2700
# ...            ...                ...
# 17041        Type1          1193.1136
# 17042  Supermarket          1845.5976
# 17043        Type2          1845.5976
# 17044  Supermarket           765.6700
# 17045        Type1           765.6700
#
# [17046 rows x 12 columns]

# %% [markdown]
# ### array contains

# %%
df_exp.withColumn('Outlet_Type_flag',array_contains('Outlet_Type','Type1')).toPandas()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998        None               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002        None               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#                Outlet_Type  Item_Outlet_Sales  Outlet_Type_flag
# 0     [Supermarket, Type1]          3735.1380              True
# 1     [Supermarket, Type2]           443.4228             False
# 2     [Supermarket, Type1]          2097.2700              True
# 3         [Grocery, Store]           732.3800             False
# 4     [Supermarket, Type1]           994.7052              True
# ...                    ...                ...               ...
# 8518  [Supermarket, Type1]          2778.3834              True
# 8519  [Supermarket, Type1]           549.2850              True
# 8520  [Supermarket, Type1]          1193.1136              True
# 8521  [Supermarket, Type2]          1845.5976             False
# 8522  [Supermarket, Type1]           765.6700              True
#
# [8523 rows x 13 columns]

# %% [markdown]
# # Group by
#
# ### Scenario 1

# %%
df.groupBy('Item_Type').agg(sum('Item_MRP')).toPandas()
# Out:
#                 Item_Type  sum(Item_MRP)
# 0           Starchy Foods     21880.0274
# 1            Baking Goods     81894.7364
# 2                  Breads     35379.1198
# 3   Fruits and Vegetables    178124.0810
# 4                    Meat     59449.8638
# 5             Hard Drinks     29334.6766
# 6             Soft Drinks     58514.1650
# 7               Household    135976.5254
# 8               Breakfast     15596.6966
# 9                   Dairy    101276.4596
# 10            Snack Foods    175433.9204
# 11                 Others     22451.8916
# 12                Seafood      9077.8700
# 13                 Canned     90706.7270
# 14           Frozen Foods    118558.8814
# 15     Health and Hygiene     68025.8388

# %%
df.groupBy('Item_Type').agg(avg('Item_MRP')).toPandas()
# Out:
#                 Item_Type  avg(Item_MRP)
# 0           Starchy Foods     147.838023
# 1            Baking Goods     126.380766
# 2                  Breads     140.952669
# 3   Fruits and Vegetables     144.581235
# 4                    Meat     139.882032
# 5             Hard Drinks     137.077928
# 6             Soft Drinks     131.492506
# 7               Household     149.424753
# 8               Breakfast     141.788151
# 9                   Dairy     148.499208
# 10            Snack Foods     146.194934
# 11                 Others     132.851430
# 12                Seafood     141.841719
# 13                 Canned     139.763832
# 14           Frozen Foods     138.503366
# 15     Health and Hygiene     130.818921

# %% [markdown]
# ### Scenario 2

# %%
df.groupBy('Item_Type','Outlet_Size').agg(sum('Item_MRP').alias('Item_MRP_sum')).toPandas()
# Out:
#                 Item_Type Outlet_Size  Item_MRP_sum
# 0           Starchy Foods      Medium     7124.1362
# 1   Fruits and Vegetables      Medium    59047.2172
# 2           Starchy Foods        None     6040.6402
# 3                  Breads        None    10011.5004
# 4            Baking Goods        None    23433.8388
# ..                    ...         ...           ...
# 59                  Dairy       Small    28896.5360
# 60     Health and Hygiene        None    19975.6632
# 61     Health and Hygiene       Small    17929.0888
# 62                 Others        High     2121.2258
# 63           Frozen Foods       Small    34321.7974
#
# [64 rows x 3 columns]

# %% [markdown]
# ### Scenario 3

# %%
df.groupBy('Item_Type','Outlet_Size').agg(sum('Item_MRP').alias('Item_MRP_sum'),avg('Item_MRP')\
                                          .alias('Item_MRP_Average')).toPandas()
# Out:
#                 Item_Type Outlet_Size  Item_MRP_sum  Item_MRP_Average
# 0           Starchy Foods      Medium     7124.1362        148.419504
# 1   Fruits and Vegetables      Medium    59047.2172        142.971470
# 2           Starchy Foods        None     6040.6402        140.480005
# 3                  Breads        None    10011.5004        139.048617
# 4            Baking Goods        None    23433.8388        126.669399
# ..                    ...         ...           ...               ...
# 59                  Dairy       Small    28896.5360        145.942101
# 60     Health and Hygiene        None    19975.6632        130.559890
# 61     Health and Hygiene       Small    17929.0888        131.831535
# 62                 Others        High     2121.2258        132.576613
# 63           Frozen Foods       Small    34321.7974        137.838544
#
# [64 rows x 4 columns]

# %% [markdown]
# ### collect list

# %%
data = [('user1','book1'),
        ('user1','book2'),
        ('user2','book2'),
        ('user2','book4'),
        ('user3','book1')]

schema = 'user string, book string'

df_book = spark.createDataFrame(data,schema)

df_book.show()
# Out:
# +-----+-----+
# | user| book|
# +-----+-----+
# |user1|book1|
# |user1|book2|
# |user2|book2|
# |user2|book4|
# |user3|book1|
# +-----+-----+

# %%
df_book.groupBy('user').agg(collect_list('book')).show()
# Out:
# +-----+------------------+
# | user|collect_list(book)|
# +-----+------------------+
# |user1|    [book1, book2]|
# |user2|    [book2, book4]|
# |user3|           [book1]|
# +-----+------------------+

# %%
df.select('Item_Type','Outlet_Size','Item_MRP').show()
# Out:
# +--------------------+-----------+--------+
# |           Item_Type|Outlet_Size|Item_MRP|
# +--------------------+-----------+--------+
# |               Dairy|     Medium|249.8092|
# |         Soft Drinks|     Medium| 48.2692|
# |                Meat|     Medium| 141.618|
# |Fruits and Vegeta...|       NULL| 182.095|
# |           Household|       High| 53.8614|
# |        Baking Goods|     Medium| 51.4008|
# |         Snack Foods|       High| 57.6588|
# |         Snack Foods|     Medium|107.7622|
# |        Frozen Foods|       NULL| 96.9726|
# |        Frozen Foods|       NULL|187.8214|
# |Fruits and Vegeta...|     Medium| 45.5402|
# |               Dairy|      Small|144.1102|
# |Fruits and Vegeta...|     Medium|145.4786|
# |         Snack Foods|      Small|119.6782|
# |Fruits and Vegeta...|       High|196.4426|
# |           Breakfast|      Small| 56.3614|
# |  Health and Hygiene|     Medium|115.3492|
# |           Breakfast|     Medium| 54.3614|
# |         Hard Drinks|     Medium|113.2834|
# |               Dairy|      Small|230.5352|
# +--------------------+-----------+--------+
# only showing top 20 rows

# %% [markdown]
# # Pivot

# %%
df.groupBy('Item_Type').pivot('Outlet_Size').agg(avg('Item_MRP')).show()
# Out:
# +--------------------+------------------+------------------+------------------+------------------+
# |           Item_Type|              null|              High|            Medium|             Small|
# +--------------------+------------------+------------------+------------------+------------------+
# |       Starchy Foods|140.48000465116277|158.15707368421053| 148.4195041666666| 150.2701736842105|
# |              Breads|139.04861666666667|         133.75896| 140.8610385542169| 145.5236507042254|
# |        Baking Goods|126.66939891891889|129.20204383561642|126.17856847290639|125.21336363636368|
# |Fruits and Vegeta...|142.57516045845267|145.57287042253515| 142.9714702179177|148.31336951219507|
# |                Meat|139.29453448275865| 137.2447902439025|136.41913154362408|145.69925042016808|
# |         Hard Drinks| 134.3875333333333| 141.9275217391304|142.83769599999994|        129.758784|
# |         Soft Drinks|133.42344360902257|131.75847346938772| 128.2696817518248| 132.8550428571429|
# |           Household|147.76930421455944|147.09752233009704|147.71133010380618| 153.9654389105058|
# |           Breakfast| 158.6750903225807|147.49058461538462|134.53751111111112|130.56802666666667|
# |               Dairy| 149.0512677419355|153.50917249999995|148.51217431192666|145.94210101010103|
# |         Snack Foods| 145.0097524096384|145.84708639999994|148.77919509803917|144.35189611940308|
# |              Others|132.59299565217393|       132.5766125|127.83618076923078|137.88921090909088|
# |             Seafood|142.21686666666668|134.86424000000002|  140.857619047619|         144.28176|
# |              Canned|140.65181123595508| 135.4427076923077|138.12485069124423|142.29542857142857|
# |        Frozen Foods|137.49448464730293|         136.82925|140.55701532846714|137.83854377510033|
# |  Health and Hygiene|130.55989019607844|135.11098032786884|128.70186470588237|131.83153529411757|
# +--------------------+------------------+------------------+------------------+------------------+
